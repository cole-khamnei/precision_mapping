# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
    
sys.path.insert(1, os.path.dirname(os.path.dirname(os.getcwd())))
import precision_mapping as pm

# Loads test suite paths
from precision_mapping.tests.constants_test_suite import *

# %%
dtseries_path = TEST_DTSERIES_PATH  # path to dtseries or .txt with lines of dtseries paths
subject_id = TEST_SUBJECT_ID  # name of subject (output directory will use this)
sample_label = TEST_SAMPLE_LABEL # sample label (normally '{subject}_additional_info')
outdir = TEST_DIR_PATH # output directory
censor_file = TEST_DTSERIES_CENSOR_FILE # path to frame censoring .dat file

pm.precision_mapping(dtseries_path, subject_id, sample_label, outdir,
                     censor_files=censor_file, device="default",
                     sparsity=0.01, n_infomaps_reps=1, overwrite=True)
# Out:
# Generating vertex-level FC:   0%|          | 0/1 [00:00<?, ?it/s]
# SparseCorrelator Block Analysis:   0%|          | 0/4278.0 [00:00<?, ?it/s]
# Running infomap parcel detection:   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING: reduced number of vertex connections. 0.7036546087947241
# Assigning parcellation networks:   0%|          | 0/1 [00:00<?, ?cifti/s]
# Created network assignments.
# /Users/cole/miniconda3/envs/nct/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py:2605: RuntimeWarning: divide by zero encountered in func (vectorized)
#   outputs = ufunc(*inputs)
# {'vertex-fc': ['/System/Volumes/Data/data/data7/network_control/projects/precision_mapping/tests/outputs/example_vertex_FC.npz'],
#  'parcel-partition': ['/System/Volumes/Data/data/data7/network_control/projects/precision_mapping/tests/outputs/example_parcel_partition.npy'],
#  'network-partition': ['/System/Volumes/Data/data/data7/network_control/projects/precision_mapping/tests/outputs/example_network_partition.npy'],
#  'parcel-dlabel': ['/System/Volumes/Data/data/data7/network_control/projects/precision_mapping/tests/outputs/example_parcels.dlabel.nii'],
#  'network-dlabel': ['/System/Volumes/Data/data/data7/network_control/projects/precision_mapping/tests/outputs/example_networks.dlabel.nii'],
#  'parcel-plot': ['/System/Volumes/Data/data/data7/network_control/projects/precision_mapping/tests/outputs/example_parcellation_plot.png'],
#  'qc-plot': ['/System/Volumes/Data/data/data7/network_control/projects/precision_mapping/tests/outputs/example_QC_plot.png']}
